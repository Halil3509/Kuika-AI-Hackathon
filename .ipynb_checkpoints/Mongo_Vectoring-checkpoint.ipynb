# %%
import pandas as pd

import time
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.output_parsers import StrOutputParser

import os
from tqdm import tqdm

# %% [markdown]
# ## Configs

# %%
os.environ['OPENAI_API_KEY'] = 'sk-proj-TimFt1navUqB43NoKCkST3BlbkFJULiZCwo4pYZg1DH4upnq'

# %%
os.environ['MONGO_DB_KEY'] = "IobZyvpsBcQRbNlS"
os.environ['MONGO_DB_CON_STRING'] = \
f"mongodb+srv://halil10hatun:{os.environ['MONGO_DB_KEY']}@mycluster.jzt34j1.mongodb.net/?retryWrites=true&w=majority&appName=MyCluster"

# %%
uretim_df = pd.read_excel('./Postre_Data/Gunluk_Uretim_Adetleri_Raporu_Tabular.xlsx')
siparis_df = pd.read_excel('./Postre_Data/Siparisler_Tabular.xlsx')

# %%
uretim_df.columns
# Out:
# Index(['Order No', 'Model Kodu', 'Model Adı', 'Müşteri', 'Bölüm', 'Tedarikçi',
#        'Müşteri Order No', 'Rpt', 'Marka', 'Renk Kodu', 'İşlem', 'RSN',
#        'Tarih', 'Adet', 'Kumaş', 'Kumaş Tipi', 'Kalite Tipi'],
#       dtype='object')

# %%
for column in uretim_df.columns:
    if uretim_df[column].dtype == 'object' or pd.api.types.is_categorical_dtype(uretim_df[column]):
        print(f"{column} eşsiz değerleri = {uretim_df[column].unique()}")
    else:
        print(f"{column}")
# Out:
# Order No eşsiz değerleri = ['ZAR220173' 'PLM16523' 'PLM16530' ... 'PLM16326' 'PLM16448' 'PLM16506']
# Model Kodu eşsiz değerleri = ['ZAR01099' 'SMP03599-005' 'DSG08620-001' ... 'DSG08529-001'
#  'DSG08576-001' 'DSG06985-004']
# Model Adı eşsiz değerleri = ['5584-377 (UTR-1062-85/360)' 'RIB CUT OUT BODYSUIT' 'UGL-345' ...
#  'UMC-P-0250' '7125 short sleeve' 'TEEW040 OPTA']
# Müşteri eşsiz değerleri = ['ITX TRADING S.A' 'PRIMARK LIMITED' 'H&M' 'C&A Buying GmbH & Co. KG'
#  'LPP COMPANY' 'Motelrocks UK Ltd' 'LC Waikiki' 'New Look'
#  'TUVAL SANAT GALERİSİ TEKS.TUR.SAN.TİC.LTD.ŞTİ.' 'ASDA STORES LIMITED'
#  'BRAVADO MERCHANDISE A DIVISION OF UNIVERSAL MUSIC GMBH'
#  'ÜNİTEKS TEKSTİL GIDA SAN DIŞ TİC. A.Ş' 'PARK AGENCIES LTD'
#  'UNIVERSAL MUSIC SPAIN S.L.U' 'BRANDDESING SA' 'MERCH TRAFFIC'
#  'WE Fashion' 'BERSHKA BSK ESPANA S.A.' 'COTTON DIVISION' 'MANGO INC.']
# Bölüm eşsiz değerleri = ['ZR05' nan 'HM01' 'CA04' 'BM06' 'ING09' 'ZR08']
# Tedarikçi eşsiz değerleri = ['AHMET KONCA(ESKİ ÜNVAN)'
#  'Numune Dikim Bandı - C&A / ING / RESERVED  / lCW / BRAVADO'
#  'Numune Dikim Bandı - ZARA' 'SİNTAŞ TEKSTİL VE TİC. LTD. ŞTİ.'
#  'MOLA TEKSTİL İNŞ. SAN. VE TİC. LTD. ŞTİ.'
#  'KARADAĞLAR KONF. TEKSTİL İNŞ. SAN. VE TİC. LTD. ŞTİ.'
#  'Numune Dikim Bandı - H&M'
#  'Numune Dikim Bandı - BERSHKA / ZARA DOKUMA  / MOTELROCKS'
#  'KUZEY KAFKAS GİYİM SANAYİ TİC. LTD. ŞTİ.'
#  'AZİM DIŞ TİCARET SAN. VE LTD. ŞTİ.'
#  'KANDEMİR TEKSTİL İNŞ. GIDA SAN. VE DIŞ TİC. LTD. ŞTİ.'
#  'STORY GİYİM ANONİM ŞİRKETİ'
#  'FAYSAL TAŞKIN TAŞKIN TEKSTİL SANAYİ VE TİC.LTD.ŞTİ.'
#  'KEPSİL TEKSTİL KONFEKSİYON SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'EZKA TEKSTİL TUR. GIDA SAN. VE DIŞ TİC. LTD. ŞTİ.'
#  'ELİF NAKIŞ TEKSTİL İNŞAAT ORMAN ÜR. SAN. VE TİC. LTD. ŞTİ.'
#  'MED TEKSTİL MEHMET SİRAÇ DEĞİRMENCİ'
#  'İEGS İÇ EGE GİYİM TURİZM SAN.VE TİC.LTD.ŞTİ.'
#  'ASLAN TEKSTİL - TEMAM TEKE (ESKİ CARİ)'
#  'ESKİ (TAŞKIN TEKSTİL FAYSAL TAŞKIN)'
#  'ALPSU ORDU TEKSTİL KONFEKSİYON SANAYİ VE TİCARET LİMİTED ŞİRKETİ(ESKİ ÜNVAN)'
#  'TEOS NAKIŞ BASKI TEKSTİL KONFEKSİYON SAN. TİC. LTD. ŞTİ.'
#  'SEFTER KURİŞ AYZE TEKSTİL'
#  'AYŞİL İNŞ. TRZ. TEKSTİL KONF. SAN. VE TİC. LTD. ŞTİ.'
#  'MURAT IŞIK TEKSTİL MEDİKAL HAM MADDE OTOMOTİV İNŞAAT TURİZM GIDA SAN. TİC. LTD. ŞTİ.'
#  'ELA DİJİTAL BASKI TEKSTİL SAN. VE TİC. LTD. ŞTİ.'
#  'ARES KONFEKSİYON İNŞ. TUR. SAN. VE TİC. LTD. STİ.'
#  'İCS TEKSTİL KONFEKSİYON SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'RONA TEKSTİL İNŞAAT TAAHHÜT İTHALAT İHRACAT GIDA SAN. TİC. LTD. ŞTİ.'
#  'ECEM SULTAN SAN. TİC. LTD. ŞTİ.'
#  'SRT GİYİM DIŞ TİCARET VE SANAYİ LİMİTED ŞİRKETİ'
#  'OR-Gİ İLETİŞİM VE TEKSTİL SAN.VE TİC.LTD.ŞTİ.'
#  'BARAN TEKSTİL KIYASETTİN ARIK(ESKİ CARİ)'
#  'ELİF SÜZENE NAKIŞ BASKI TESKTİL SAN.VE TİC.LTD.ŞTİ'
#  'ÖZKOÇ MODA SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'HANO TEKSTİL İNŞAAT GIDA NAKL. SAN. VE TİC. LTD. ŞTİ.'
#  'EMPAŞ EMPRİME TEKSTİL SAN. LTD. ŞTİ.'
#  'BKA EMPRİME BASKI VE TEKSTİL SANAYİ TİCARET ANONİM ŞİRKETİ'
#  'ÇAĞAN İLİK TEKSTİL İNŞ. TUR. GIDA SAN. TİC. LTD. ŞTİ.'
#  'UÇARLAR MAKİNA TEKSTİL İNŞ. İTH. İHR. SAN. VE TİC. LTD. ŞTİ.'
#  'TREND KURU TEMİZLEME TEKSTİL ÜRÜNLERİ GELİŞTİRME SAN. VE TİC. A.Ş.'
#  'DİJİTAL TEKSTİL SANAYİ VE DIŞ TİCARET LİMİTED ŞİRKETİ'
#  'ASEL MODATEKS TEKSTIL SANAYI VE TICARET LIMITED'
#  'AKAR TEKSTİL GIDA VE TURİZM SAN. TİC. A.Ş.'
#  'SE TEKSTİL İNŞAAT TARIM GIDA NAKLİYE TAAHHÜT İTHALAT İHRACAT SAN. TİC. LTD. ŞTİ.'
#  'DENGE YIKAMA SAN. TİC. LTD. ŞTİ.'
#  'AMASYA ELÇİN TEKSTİL İMALAT İTHALAT İHRACAT SAN. VE TİC. LTD. ŞTİ.'
#  'AYDEMA TEKSTİL OTOMOTİV DANIŞMANLIK İNŞAAT TURİZM İTHALAT İHRACAT SANAYİ VE TİC. LTD.ŞTİ'
#  'DESMA MODA TEKSTIL SANAYI TICARET LIMITED SIRKETI'
#  'LİVA HAZIR GİYİM BOYAMA LTD. ŞTİ.'
#  'AYÇ TEKSTİL SANAYİ VE TİC. LTD. ŞTİ.'
#  'CLS TEKSTİL SANAYİ TİCARET ANONİM ŞİRKETİ'
#  'HANİFE ALTUNER - ALTA TEKSTİL '
#  'STRABON MEDİKAL TIBBİ ÜR.TEKSTİL PAZ. İTH. İHR. SAN.TİC.LTD. ŞTİ.'
#  'METİNCE TEKS. İNŞ. TAR. HAY. LTD. ŞTİ.'
#  'EV-KON TEKSTİL SANAYİ VE TİC. A.Ş.'
#  'NİKSAR ASLAN TEKSTİL SAN. VE TİC. LTD.ŞTİ.'
#  'ÖZAR TEKSTİL İÇ VE DIŞ TİC. SAN. LTD. ŞTİ.'
#  'ALZ TEKSTİL İNŞAAT SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'İRF TEKSTİL İNŞ. TURİZM GIDA SAN. TİC. LTD. ŞTİ.'
#  'SİBATEX TEKSTİL SANAYİ VE TİCARET ANONİM ŞİRKETİ'
#  'YMO TEKSTİL İNŞ. SAN. İÇ VE DIŞ TİC. LTD. ŞTİ.'
#  'MİRHAT HAZIR GİYİM SAN. VE TİC.LTD.ŞTİ'
#  'KAYATEK TEKSTİL İNŞAAT SAN.VE TİC.LTD.ŞTİ.'
#  'MENESA TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'ALTATEKS GRUP TEKSTİL SAN.TİC.LTD.ŞTİ.'
#  'MKM PRINT TEKSTİL İTH. İHR. SAN. VE TİC. LTD. ŞTİ.'
#  'FATSA EKİP TEKSTİL İNŞ. SAN. TİC. LTD. ŞTİ.'
#  'SPC MÜHENDİSLİK İNŞ. TAAH. TEKS. NAK. İTH. İHR. SAN. VE TİC. LTD. ŞTİ.'
#  'MEDİ AKSESUAR DÜNYASI SAN. VE TİC. LTD. ŞTİ.'
#  'EBRU TEKSTİL NAKIŞ SAN. VE TİC. LTD. ŞTİ.'
#  'NEWTEX HAZIRGİYİM TEKSTİL KONFEKSİYON SAN. VE TİC. A.Ş.'
#  'LİDER CANSU TEKSTİL SAN. VE TİC. A.Ş.'
#  'GÜNDÜZ NAKIŞ TEKS. GIDA TUR. İNŞ. SAN. VE TİC. LTD. ŞTİ.'
#  'EKİP TEKSTİL İNŞAAT TURİZM GIDA SANAYİ VE DIŞ TİCARET ANONİM ŞİRKETİ'
#  'İKİNCİ BAHAR TEKSTİL GÖMLEK VE KONFEKSİYON SANAYİ TİCARET LİMİTED ŞİRKETİ'
#  'İMZA GRUP TEKSTİL TİCARET SANAYİ LİMİTED ŞİRKETİ'
#  'SUN-SET EMPİRME TEKSTİLl SAN.VE DIŞ TİC. LTD. ŞTİ.'
#  'DOĞAN STİL TEKSTİL TUZR. İNŞ. SAN. VE TİC. LTD. ŞTİ.'
#  'BEY-DUR KONFEKSİYON İMALAT İHRACAT SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'CTT TEKSTİL TURİZM İNŞAAT SANAYİ TİCARET LİMİTED ŞİRKETİ'
#  'ASYA NAKIŞ TEKSTİL SAN. VE TİC. LTD. ŞTİ.'
#  'AS BASKI NAKIŞ ÖRME TEKSTİL SAN. TİC. A.Ş.'
#  'OSM HAZIR GİYİM TEKSTİL GIDA İNŞAAT NAK. SAN. VE TİC. A.Ş.'
#  'ORFA GİYİM SANAYİ VE DIŞ TİCARET A.Ş.'
#  'ALPSU İNŞAAT TEKSTİL SAN. VE TİC. LTD. ŞTİ.'
#  'BETA KONFEKSİYON TEKSTİL İHRACAT İTHALAT SAN. VE TİC. LTD. ŞTİ.'
#  'ONLY GİYİM TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'ARMEN MODA GİYİM TEKSTİL İNŞAAT TURİZM DIŞ TİCARET LİMİTED ŞİRKETİ'
#  'OSKA DİKİM TEKSTİL İNŞAAT GIDA SAN. VE TİC. LTD.ŞTİ.'
#  'ÖZ SIRAÇ TEKSTIL GIDA TURIZM NAKLIYE ITHALAT İHRACAT SAN.VE TİC. LTD. ŞTİ.'
#  'DEM ÖZKANLAR TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'TEKOVA TEKSTİL ÜRÜNLERİ TURİZM İNŞ. GIDA SAN. VE TİC. LTD. ŞTİ.'
#  'KILIÇ MODA TEKSTİL SAN VE TİC LTD ŞTİ'
#  'DİBATEKS BASKI NAKIŞ KONF. SAN. VE TİC. LTD. ŞTİ.'
#  'UĞUR21 MODA TEKSTİL İNŞAAT TARIM GIDA NAKLİYE SANAYİ TİCARET LİMİTED ŞİRKETİ'
#  'MAG GRUP KUMAŞ KONFEKSİYON TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'SMART ÖRME TEKSTİL LTD. ŞTİ.'
#  'VESA TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'ASLANKAYA TEKSTİL SANAYİ VE TİC. LTD. ŞTİ.'
#  'SİLİVA TEKSTİL İNŞ. NAK. TAR. SAN. TİC. LTD. ŞTİ.'
#  'PRONTO FASHİON MODA KONFEKSİYON ANONİM ŞİRKETİ'
#  'MFB TEKSTİL İNŞ. TAAH. GID. TUR. SAN.TİC.LTD.ŞTİ.'
#  'RBK YATIRIM TEKSTİL ANONİM ŞİRKETİ'
#  'BALEKAN KONFEKSİYON VE İNŞAAT SANAYİ TİCARET LİMİTED ŞİRKETİ'
#  'ALDEBARAN TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'KONCA KONFEKSİYON TEKSTİL SANAYİ VE TİCARET ANONİM ŞİRKETİ'
#  'EMTAŞ TEKSTİL İNŞAAT TAAHHÜT GIDA TURİZM HAYVANCILIK SA.TİC.LTD.ŞTİ.'
#  'RUKİYE DİDEM ÖNÜR - ONURCAN TEKSTİL'
#  'SİDAR EMPRİME BASKI SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'KIYASETİN ARIK BARAN TEKSTİL KONFEKSİYON SANAYİ VE TİCARET ANONİM ŞİRKETİ'
#  'UGS GİYİM SANAYİ VE TİCARET ANONİM ŞİRKET'
#  'SELİS EMPRIME TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'ZAROTEKS TEKSTİL İNŞ. TAAH. İTH. İHR. PAZ. SAN. VE TİC. LTD. ŞTİ.'
#  'YMZ ÖZMEN TEKSTİL SANAYİ TİCARET LİMİTED ŞİRKETİ  ' nan
#  'MERAM YATIRIM İNŞAAT NAKLİYAT SAN. VE TİC. LTD. ŞTİ. '
#  'BAZEM İNŞAAT TEKSTİL SAĞLIK HİZMETLERİ LİMİTED ŞİRKETİ'
#  'TOPRAK AKARYAKIT YAYINCILIK HAY. TAR. GID. İNŞ. TE. SAN. TİC. LTD. ŞTİ. '
#  'ITX TRADING S.A' 'LPP COMPANY'
#  'BH TEKSTIL INSAAT SANAYI VE TICARET LIMITED SIRKETI' 'AHMET SÜZEN'
#  'New Look' 'POTKOVA TEKSTİL KONF. GIDA TUR. SAN. VE TİC. LTD. ŞTİ. '
#  'C&A Buying GmbH & Co. KG' 'ÖZLEM TOKKAMIŞ - SEHER TEKSTİL'
#  'AGEV TEKSTİL İTHALAT İHRACAT SANAYİ VE TİCARET ANANONİM ŞİRKETİ'
#  'GÖRTEKS TEKSTİL TURİZM  SAN.VE TİC.LTD.ŞTİ.'
#  'ARTKAR TEKSTİL SAN. TİC. LTD. ŞTİ.' 'PERİDOT TEKSTİL SAN. TİC.LTD.ŞTİ.'
#  'VEHA KONFEKSİYON SAN. VE TİC. LTD. ŞTİ.'
#  'AKDEM HAZIR GİYİM DIŞ TİCARET LİMİTED ŞİRKETİ'
#  'SUMMANİ AYDENİZ AYCEM TEKSTİL'
#  'TANEKS TEKSTİL SAN. VE DIŞ TİC. LTD. ŞTİ.'
#  'DOĞUŞ HAZIR GİYİM SANAYİ VE TİC. LTD. ŞTİ.'
#  'BAKAY TEKSTİL GIDA TARIM HAYVANCILIK TAŞ. İTHALAT İHRACAT SAN. VE TİC.LTD.ŞTİ.'
#  'NU DEM TEKSTİL VE NAKIŞ SAN. TİC. LTD. ŞTİ.'
#  'GÜNIŞIĞI TRANSFER BASKI TEKSTİL SAN.VE TİC.LTD.ŞTİ.'
#  'ÜNİTEKS TEKSTİL GIDA SAN DIŞ TİC. A.Ş'
#  'PER BOYA TEKSTİL SAN. VE TİC. LTD.ŞTİ ( ESKİ CARİ )'
#  'Y MOMENTUM TEKSTİL DIŞ TİC.A.Ş'
#  'PER BOYA TEKSTİL SANAYİ VE TİCARET A.Ş.' 'İBRAHİM FİDAN - FİDAN KROŞETA'
#  'MARİZ TEKSTİL SANAYİ VE TİCARET LİMİTED ŞİRKETİ'
#  'NY NAKIŞ TEKS. KONF. SAN. TİC. LTD. ŞTİ.' 'ÖZGÜN BOYA SAN. TİC. A.Ş.'
#  'UZMAN SÜS DİKİŞLERİ TEKSTİL SAN. VE TİC. LTD ŞTİ.'
#  'BERRAKÖZ KONFEKSİYON EMPRİME SAN. VE TİC. LTD. ŞTİ.'
#  'TİME TEKS TEKSTİL AKS. İML. SAN. VE DIŞ TİC. LTD. ŞTİ.']
# Müşteri Order No eşsiz değerleri = ['17011-25' nan '17013-25' ... '59182-D' '272385-1636' '221424-2032']
# Rpt
# Marka eşsiz değerleri = ['Zara' 'Primark' 'H&M' 'C&A' 'Stradivarius' 'Reserved' 'Motel Rocks'
#  'Bershka' 'Lc Waikiki' 'New Look' 'TREADLER' 'PULL&BEAR'
#  'TUVAL SANAT GALERİSİ TEKS.TUR.SAN.TİC.LTD.ŞTİ.' 'GEORGE' 'BRAVADO'
#  'Uniteks' 'Lefties' 'WE Fashion' 'OYSHO' 'BRANDDESING SA' 'MANGO']
# Renk Kodu eşsiz değerleri = ['800 - Black' '0800 Black' 'Check Aop' ... '11-0601' '13-0849 TCX'
#  '16-115']
# İşlem eşsiz değerleri = ['Ütü Paket' 'Kesim' 'Dikim' 'Nakış' 'Parça Baskı' 'Smok' 'Parça Boyama'
#  'Parça Yıkama' 'Çift boya' 'Yağ Sökümü' 'Taş Pres' 'Silikon' 'İlik Düğme'
#  'Pres' 'Çıt Çıt' 'Fikse' 'Şardon' 'Ram' 'Yıkama' 'Orta boya' 'Koyu boya'
#  'Termofikse' 'El İşçiliği' 'Enzim'
#  'Reaktif baskı zemin kasar beyaz yıkama' 'Açık boya'
#  'Pigment baskı açık zemin üzeri  byl  '
#  'Reaktif baskı açık zemin üzeri  byl' 'Gaze']
# RSN eşsiz değerleri = [nan '64301 665 05 116' '64301 705 37 201' ... '210673302' '210597007  '
#  '210490998']
# Tarih
# Adet
# Kumaş eşsiz değerleri = [nan 'Örme Mesh 100D %80 Rcy Pes %20 Ea 80 Gr'
#  'Süprem 30/1 %100 Org Co 145Gr' ...
#  'Çelik Raporlu Ribana 28/(70/40) %49 Pes %47 BCI Co %4 Ea'
#  'Tül 40/40 %95 Pes %5 Ea' 'IRMAK 26-22 İPEKTÜL']
# Kumaş Tipi eşsiz değerleri = [nan 'Ana Kumaş' 'Diğer Kumaş']
# Kalite Tipi eşsiz değerleri = ['Sağlam' 'Kumaş Hatası' 'Dikim Hatası' 'Kumaş Kaynaklı Leke'
#  'İhracat Fazlası' 'Renk Farkı' 'Numune' 'Parça İade' 'Nakış Hatası'
#  'Baskı Kaynaklı Leke' 'Baskı Hatası' 'Taş Pres' 'Ölçü Hatası'
#  'P.Boya Hatası' 'P.Boya Kaynaklı Leke' 'El İşçiliği Hatası' 'Fire' 'İade'
#  'Tanımsız']
# C:\Users\halilibrahim.hatun\AppData\Local\Temp\ipykernel_2080\881317359.py:2: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if uretim_df[column].dtype == 'object' or pd.api.types.is_categorical_dtype(uretim_df[column]):

# %%
for column in siparis_df.columns:
    if siparis_df[column].dtype == 'object' or pd.api.types.is_categorical_dtype(siparis_df[column]):
        print(f"{column} eşsiz değerleri = {siparis_df[column].unique()}")
    else:
        print(f"{column}")
# Out:
# Durum eşsiz değerleri = ['Açık' 'Kapalı']
# Statü eşsiz değerleri = ['Planlandı' 'İptal Edildi' 'Onay Bekliyor' 'Başladı - Çalışıyor'
#  'Tamamlandı' 'Hazır' 'Durduruldu' 'Tedarik Bekliyor']
# Booking -> Order eşsiz değerleri = ['EVET' 'HAYIR']
# Set Order eşsiz değerleri = ['HAYIR' 'EVET']
# Set Parça Sayısı eşsiz değerleri = [nan '1' '2 Parça' '3 Parça' '7 Parça' '8 Parça' '3' '2']
# Order Tipi eşsiz değerleri = ['Firm Order' 'Booking Order']
# Booking Type eşsiz değerleri = ['Müşteri' '-']
# Order Grubu eşsiz değerleri = [nan '208695-7618' '130094-7819 set' 'SET ' '64301 344 43 814 SET' 'set'
#  '132170-7618' '132485-8718' '132402-8718' '272198-7618 ' '272195-7618'
#  '272402-7819' '131942-7618 ' '129816-8815' '264176-7618' 'SET' '2209535'
#  'shop order' 'shane mıne craft']
# Satış Tipi eşsiz değerleri = ['Tasarım Koleksiyonu' 'Müşteri Koleksiyonu' ' ' 'Kumaş Koleksiyonu'
#  'Tasarım Kolleksiyonu' 'Alışveriş Koleksiyonu']
# Sertifikasyon eşsiz değerleri = ['BCI + RCS' 'BCI' nan 'JL - Care For Fiber' 'RCS'
#  'JL - Care For Fiber + OCS' 'OCS + RCS' 'JL - Care For Fiber + RCS'
#  'C&A Warner Bros' 'OCS' 'JL - Care For Water + BCI' 'RCS + New Look Kind'
#  'JL - Care for Water' 'JL - Care for Fiber + Inditex Children'
#  'BCI + H&M Disney' 'RCS + H&M Disney'
#  'JL - Care For Water + BCI + Inditex Children' 'C&A Disney'
#  'New Look RCS' 'Inditex Children' 'BCI + RCS + H&M Disney'
#  'BCI + C&A Disney' 'BCI + C&A Warner Bros' 'H&M Disney'
#  'BCI + RCS + H&M NFL' 'BCI + H&M NFL'
#  'JL - Care for Fiber + RCS + Inditex Children' 'RCS + H&M NFL'
#  'BCI + New Look Kind' 'H&M NFL'
#  'RCS + H&M “Müşteri onayı aranmayan lisans türü” '
#  'H&M “Müşteri onayı aranmayan lisans türü” '
#  'OCS + H&M “Müşteri onayı aranmayan lisans türü” '
#  'BCI + H&M “Müşteri onayı aranmayan lisans türü” '
#  'BCI + RCS + H&M “Müşteri onayı aranmayan lisans türü”' 'H&M Hasbro'
#  'BCI + RCS + C&A Sanrio' 'BCI + RCS + C&A Disney']
# Order No eşsiz değerleri = ['H&M241061' 'H&M241062' 'H&M241063' ... 'H&M241060' 'H&M241059'
#  'ZAR240240']
# Order Geliş Tarihi
# Sisteme Giriş Tarihi
# Satır ya da Sütun M.İsteme Tarihi
# YIL
# AY
# HAFTA
# ÇEYREK eşsiz değerleri = ['Q3' 'Q2' 'Q4' 'Q1']
# Müşteri Order No eşsiz değerleri = ['969495-1636' '969665-1636' '970190-8716' ... '967870-5848' '968016-5882'
#  '93447-D']
# RPT
# Açıklama eşsiz değerleri = [nan 'TOD29' 'PİLOT' 'OPD 20 TOD 24' 'carving provider 97'
#  'carving provider 98' 'carving provider 99' 'OPD W22- TOD W28'
#  'OPD W24 TOD W31' 'OPD W30 TOD W36' 'OPD27 TOD32' 'TOD 28'
#  'opd w20 tod w26' 'ROI' 'REPEAT' 'cami' 'İPTAL' 'opd 48 tod 52 online '
#  'opd 01 tod wk 05 online ' 'opd06 tod wk110 online '
#  'opd wk 46 tod wk 50  shop ' 'opd wk 50 tod wk02  shop'
#  'opd wk 07 tod wk 11 shop' 'pilot numuneleridir' 'BLACK FLORAL AOP'
#  'KENTUCKY BLUE FLORAL AOP' 'GREEN - PILOT' 'GREEN' 'COLOUR  2'
#  'COLOUR  3' '12-106 White Dusty Light' 'BRIDAL ROSE TIE DYE AOP'
#  'BRIDAL ROSE AOP' 'TEKLİ PAKETLEME- SOLID' 'PLANE' 'ASOS'
#  'özel testi var' 'CPSI TESTİ ' '07-194 grey medium dusty '
#  'white dusty light' 'beden aop' 'ense biye ;56-321' 'dıkkat beden metraj'
#  'SNOW WHITE FLORAL AOP' 'PASTEL LILAC FLORAL AOP'
#  'PİGMENT METRAJ BASKILI' 'metraj baskılı' 'ONLINE- ALARMSIZ' 'ASORTİLİ'
#  'SOLİD' 'PİLOT NUMUNESİ' 'BCI COT' 'MODEL ASİT YIKAMA+PARÇA BOYAMALIDIR'
#  'black' 'PIGMENT TIE DYE METRAJ BASKILI' 'renk referansı ' 'RCYCLE COT'
#  'pantone ' 'solid' 'asortili' 'preshipment' 'opd wk41 tod w46'
#  'opd wk 41 tod w47' 'opd wk43 tod w48' 'opd wk46  tod 51'
#  'opd wk46  tod 52' 'opd wk 40 tod 45' 'opd wk 41 tod wk 46  shop '
#  'opd wk 41 tod wk 51 shop ' 'opd  wk41 tod wk 46 online '
#  'opd wk 41 tod wk51 online ' 'opd wk 50 tod wk 03 '
#  'opd wk 41 tod wk 46 onlıne ' 'opd wk41 tod wk01 online '
#  'opd wk 45 tod wk 50 online ' 'opd wk 45 tod wk 5 online '
#  'opd wk 45 tod wk 50 ' 'opd wk 45 tod wk 5 ' 'ONLINE-ALARMSIZ'
#  'BATİK METRAJ ' 'metraj baskılı ' 'solid beden , ense süpremi 56-321'
#  '18-1660tcx oldu' 'BCI cot' 'FLORAL METRAJ BASKILI'
#  '2li paketleneck siyah-pembe' '2 li paketlenecek siyah-pembe' 'thsirt'
#  '9000 ADET İPTAL' 'PRESHİPMENT' 'PRESHIPMENT' 'HAM BAŞLATILACAKTIR'
#  'MERLIS REC INTERLOK' 'MERLIS RECY INTERLOK' 'NEW' 'mavi' 'mavi '
#  'grimelanj' 'lacivert' 'opd wk 46 tod wk 51 online '
#  'opd wk 46 tod wk 07  online ' 'opd wk 52  tod wk 14 online '
#  'opd wk 52 tod wk 14 online ' 'opd wk 49 tod wk 11 store '
#  'opd wk49 tod wk11 store' 'opd wk 50 tod wk 12 store '
#  'opd wk 51 tod wlk 12 online ' 'opd wk 50 tod wk 11 store'
#  'opd wk 51 tod wk 12 online ' 'opd wk 50 tod wk 11 store '
#  'opd wk 46 tod wk 08 online ' 'opd wk 51 tod wk13 online '
#  'opd wk 45 tod wk 07 store' '3lü paket' 'RPT SİYAH' 'RPT  MİNK' 'LH'
#  'opd 47, tod w52 shop ' 'opd 50, tod  w3 shop ' 'opd 02, tod  w07 online'
#  'opd 50, tod w3 online' 'OPD W52,TOD W5 online ' 'OPD W52,TOD W8 online '
#  'OPD W52,TOD W5 shop' 'OPD W52,TOD W8  shop' 'OPD W48 , TOD W01 online'
#  'OPD W48, TOD W04 online ' 'opd wk 46 tod wk 07 store '
#  'opd wk 46 tod wk 07 online' 'opd wk 46 tod wk 07 onlime ' 'trial'
#  'OPD WK 46 TOD WK 07 ONLİNE ' 'OPD WK 46 TOD WK 07 store'
#  'opd wk 48 tod wk10 online ' 'aop baskılı interlok' 'opd wk 01 '
#  'MERTAJ BASKILI' 'DIKKAT 3LÜ SET ' '15k olarak revize edildi. '
#  '5k olarak revize edildi. ' '3lü paket- marvel desen' 'tekli /set değil '
#  'tekli satılacak /set değil ' 'tekli satılacak ' 'teklı satılır '
#  'teklı satılır' 'TEKLI SATILACAK ' 'COLOUR-1' 'COLOUR-2'
#  'CONOSUR RPT-8 EK ADET' 'opd wk03 tod wk08 ' 'opd wk03 tod wk 15'
#  'opd wk 04 tod wk 09' 'opd wk 04 tod wk 16' 'opd wk 04 tod wk 09 '
#  'opd wk 09 tod wk 16' 'opd 04 tod wk 09 ' 'opd wk04 tod wk09 '
#  'opd wk04 tod wk 18' 'opd wk 04 tod wk 16 ' 'Solid varyant'
#  'pre shipment' 'SHOP' 'ONLINE' 'pre shıpment' 'tod wk15 online '
#  'tod wk 20 online ' 'tod wk21 online ' 'tod wk 16 shop '
#  'tod wk 18 shop ' 'tod wk 21 shop ' 'tod wk 23 shop ' 'tod wk 25 shop '
#  'online opd01 tod 06 ' 'shop opd01 tod 06 ' 'shop opd 01 tod 06 '
#  'FSS SİPARİŞİDİR ' 'solid varyant' 'SOLİD OPD WK 11 TOD WK 27'
#  'SOLİD OPD WK14 TOD WK20 ' 'SOLİD OPD WK14 TOD WK27 '
#  'SOLİD OPD 11 TOD  WK 16 ' 'SOLİD OPD WK 19 TOD WK 24 '
#  'SOLİD OPD WK 19 TOD WK 32 ' 'SOLİD OPD WK 22 TOD WK27 '
#  'SOLİD OPD WK22 TOD WK 36 ' 'SOLİD OPD WK 26 TOD WK32 '
#  'SOLİD OPD WK16 TOD WK 22 ' 'SOLİD OPD 21 TOD WK 26 '
#  'MELANJ OPD 14 TOD 20 ' 'MELANJ OPD 14 TOD 28 ' 'MELANJ OPD 19 TOD 24 '
#  'MELANJ OPD 22 TOD WK27 ' 'MELAJ OPD 12 TOD WK17 '
#  'MELANJ OPD 12 TD WK 28 ' 'FSS SİPARİŞİDİR. '
#  '5584-411 SS22 RPT-18 DEN ÇEKİLECEKTİR. ' 'repeat' 'roi'
#  'adet 595 e düşürüldü. ' 'elde kalan 1. kalite fazlalıklar dahil edildi'
#  'new' '99' '96' '97' 'PİLOT NUMUNELERİDİR' 'tod wk17' 'pilot orderıdır'
#  'PİLOT NUMULERİDİR' 'pilot numuneleri' 'QUICK DRY OLMALI' 'COLOR-1'
#  'Pilot numuneleridir' 'VERY' 'ROI PO' 'ASOS WHOLE SALE'
#  'ASOS SİPARİŞİ-alarmsız'
#  'Bu yüklemede indirim var, fiyat 3,56eur olacak.' 'URBAN SAMPLES'
#  'DOLL KILL SAMPLES' 'NELLY SAMPLES' 'ASOS SAMPLE' 'DOLL KILL SAMPLE'
#  'GLENBEIGH SAMPLE' 'URBAN SAMPLE' 'GENERAL PANTS SAMPLE'
#  'DOLLS KILL SAMPLE' 'opd22 tod 27 ' 'opd w16' 'opd w26' 'opd w30'
#  'opd w32' 'opd w14' 'opd w17' 'opd w19 ' 'ROI '
#  'Online - fiyatsız, alarmsız' 'yurtdısı adetler' 'renk kodu temsilidir'
#  'TIE DYE' 'online, alarmsız, fiyatsız' 'opd 17 tod 23' 'opd17 tod 34 '
#  'Pilot numunesidir' 'pilot' 'uçak' 'yurtıcı' 'yurtdısı' 'AÇIK  ÜRÜNLER'
#  'KOLİLİ' 'alarmsız, fiyatsız online' 'KOLİLİ  ÜERÜNLER' 'KOLİLİ ÜRÜNLER'
#  'YURT DIŞI AÇIK  ÜRÜNLER' 'YURT DIŞI KOLİLİ ÜRÜNLER' 'AW COMPASSION'
#  'AW ACC BACK CIRCLE' 'AW POWER ENGINE' 'YURT İÇİ' 'YURT  DIŞI'
#  'SRS ORDER' 'alarmsız, fiyatsız' 'OPD WK 24 TOD WK29 TEK YÜKLEME '
#  'ALARMSIZ' 'PİLOT ORDER' 'ARNAVUTLUK ' 'conosour' 'AOP' 'ASOS GERMANY'
#  'ASOS US' 'EU MARKETPLACE' 'yurtiçi' 'yurtdışı' 'ORFA 6.08' 'KAFKAS 6.08'
#  'ÖZKOÇ 13.08' 'ÖZKOÇ 20.08' 'ÖZKOÇ 27.08' 'asos  us' 'asos germany'
#  'asos wholesale' 'UÇAK' 'TIR' 'COLOUR  2 - PILOT' 'COLOUR  3 - PILOT'
#  'zalando' 'Polonya yuklemesı' 'Metaho renginin aynısı'
#  'PİLOT NUMUNELERİDİR.' 'LISANSOR NUMUNELERI' 'roı' 'Rusya yuklemesı'
#  'gold' 'URBAN ORDER' 'yurtıcı sıparısı ' 'yurt dısı sıparısı'
#  'opd 35 tod 41 ' '99 asorti' '97 asorti' 'opd wk 37 tod wk 41 '
#  'deneme toplar yapılıyor' 'shop opd wk 43 tod wk48 '
#  'online opd wk43 tod wk 48 ' 'opd wk37 ' ' ' 'DOTCOM'
#  'LABDİP GÖNDERİLCEK.'
#  'KOLİLİ YÜKLEME. DOTCOM SİPARİŞİ.LABDİP ONAYI ALINACAK.' 'EU MARKEPLACE'
#  'opd w45 tod w49 - tod w08' 'opd w45 tod w49 tod w08 ' 'ASOS WHOLESALE'
#  'ASOS WHOSALE' 'PİLOT NUMUNE' 'opd 41 tod 45 ' 'opd43 tod 47'
#  'OPD 42 TOD 47 ' '97 ASORTİSİ' '99 ASORTİSİ'
#  'PİLOT OLARAK DHL İLE GÖNDERİLECEKTİR. ' 'fss ' 'pilot yüklemesidir'
#  'GENERAL PANTS SAMPLES' '20 ton ** 100.000 adet için ham kumaş'
#  '10 ton ** 50.000 adet için. ' '10 ton ** 50.000 adet için'
#  'opd wk 47 tod 51 store' 'opd wk 50 tod wk 02 store '
#  'opd 02 tod 06 online ' 'pre' 'PRE-SHIPMENT' 'YURTDIŞI-AÇIK ÜRÜNLER '
#  'YUTRDIŞI -KOLİLİ ÜRÜNLER' 'YURTİÇİ-AÇIK ÜRÜNLER'
#  'YURTİÇİ-KOLİLİ ÜRÜNLER' 'YURTDIŞI-AÇIK ÜRÜNLER'
#  'YURTDIŞI-KOLİLİ ÜRÜNLER' 'YURTİÇİ-AÇIK ÜRÜNLER '
#  'YURTDIŞI-AÇIK  ÜRÜNLER' 'YURTİÇİ-AÇIK  ÜRÜNLE' 'YURTİÇİ-AÇIK ÜRÜNLE'
#  'opd 04 tod 08 ' 'opd 06 tod 11-12' 'opd 08 tod 12 ' 'opd 11 tod 15 '
#  'opd 07 tod 11 ' 'opd 03 tod 07' 'opd wk 01 tod wk 06 store '
#  'opd wk 05  tod wk 09 shop ' '97 asortisi' '99 asortisi' 'opd w50'
#  'OPD WK 05 TOD WK 09 ONLİNE ' '.' 'PINK' '1. BULK' '2. BULK' 'ZALANDO'
#  'opd 03 tod wk 07 online ' 'opd 05 tod wk 09  shop'
#  'opd 02 tod wk 06 online ' 'opd 05 tod wk 09 store '
#  'opd wk 04 tod ek 08 online ' 'opd 01 tod wk 06 store '
#  'opd 01 tod wk 06 ' 'FCA İSTANBUL ' 'SEA KCH' 'FCA İSTANBUL' 'KCH PORT'
#  'KCH PORT ' 'TRUCK GDANSKİ' 'TRUCK GDANSKI' 'opd wk 02 tod wk 06 store'
#  'TRUCK' 'TRCUK' 'SEA KCH  PORT ' 'SEA KCH PORT' 'truck' '40650-D / 1'
#  '40650-D / 2' '1. KALİTELER' '42344-25/1' '42344-25/2' '42348-25 / 1'
#  '42348-25 / 2' 'opd 01 tod 06 online ' 'opd 01 tod 06 store '
#  'PRUSZCZ GDANSKI  TRUCK' 'PRUSZCZ GDANSKI  TRUCK      '
#  'PRUSZCZ GDANSKI  TRUCK   ' 'opd 01 tod wk 05 ' 'GDANSKI TRUCK - Solid'
#  'GDANSKI TRUCK- 2 pack' 'Pruszcz Gdański - Solid' 'Pruszcz Gdański'
#  'PRUSZCZ GDANSKI' '42532-25/2 ' '42532-25/3' 'DOTCOM ' '42644-25/1'
#  '42644-25/2' 'PİLOT YUKLEMESİDİR' 'opd 12 tod 16 ' 'opd 03 tod 07  shop '
#  'ASOS SİPARİŞİ' 'örgü başlatılabilmesi için renk seçilmiştir.' 'TOD w09'
#  'PİLOT NUMUNESİDİR. ' 'PİLOT NUMUNESİDİR.' 'ham stok'
#  'PİLOT YUKLEMESIDIR' 'sea' 'PILOT YUKLEMESIDIR' 'SOLID VARYANT'
#  'opd 22 tod 26 ' 'AOP VARYANT' 'opd 12  tod 16' 'opd12 tod 17 '
#  'opd 10 tod 17 ' 'OPD W13 - W14 // İPLİK ALINMASI İÇİN AÇILAN BOOKING'
#  'tod w17' 'OPD W13 - W14' 'tod 20' 'Zalando' 'opd 14 tod 19'
#  'opd wk 49 tod wk 02 shop' 'opd wk 49tod wk 02 online ' 'opd w13 tod w20'
#  'opd 13 tod 20' 'opd 14 tod 20 ' 'opd20 tod 24 '
#  '1,5 cm 12-0812tcx, 0,6 cm 13-0840tcx olacaktır.' 'Preshipment'
#  'opd w15 tod w20' '1,5X1,5 CM SİYAH BEYAZ ÇİZGİLİ İPLİĞİ BOYALIDIR'
#  'SOLID RENK OLMALI' 'tod 27' 'tod 31 ' 'opd 18 tod 25 mşteri aradı  '
#  'opd 22tod 26' 'opd 21 tod 25 shop   ' ' opd 21 tod 25online '
#  'opd 21 tod 27 ' 'opd  21 tod 27' 'opd 21 tod 27' 'opd 39 tod 44'
#  'online opd 24 tod 30 ' 'online opd 32 tod 37' 'opd 24 tod 30 shop '
#  'opd 29 tod 34 shop ' 'online opd 30 tod 35 ' 'shop  opd 24 tod 30 '
#  'shop opd 30 tod 35 ' 'Opd w23 tod w28' 'ALPSU' 'KEPSİL'
#  'RENK BELLİ DEĞİL' 'sıfırlandı' '240 gsm' '220 gsm'
#  'siyah renk iptal oldu' 'tod 32-33-34' 'ALARMSIZ '
#  'H101CY beige melange renk' 'VCP 10' 'PRE-SHIPMENT - ALARMSIZ'
#  'ALARM OLMAYACAK ZALANDO SİPARİŞİ' 'PİLOT NUMUNEDİR' 'PİLOT NUMUNEDİR.'
#  'PİLOT YUKLEMESIDIR /UNITEKSE GONDERINIZ ' 'BU SATIR İPTAL.'
#  'opd wk 04  tod  08 online ' 'opd wk 04  tod wk 08 shop'
#  'opd w33 // tod w39-w45-w46 MELANGE VARYANT' 'opd w20 // yıkamalı ürün'
#  'opd w32 // yıkamalı ürün' 'opd w36 // yıkamalı ürün'
#  'opd w14 // yıkamalı ürün' 'opd w17 // yıkamalı ürün'
#  'opd w21 // yıkamalı ürün' 'opd w20 // AOP - yıkamasız' 'CN' 'US' 'EU'
#  'sadece iplik alımı için ' '10.000 adet' '7500 adet' '7000 adet'
#  'SEA KCH ' 'Pruszcz Gdański - 2 pack' '42532-25/1' 'ASOS '
#  'GDANSKI TRUCK - 2 pack' 'Pruszcz Gdański - 2 Pack' 'SEA KCH  PORT'
#  'H185R antrasite melange renk' 'pilot yuklemesidir ' 'PİLOT YÜKLEMESİDİR'
#  'ASLAN' 'bu satır iptal ' 'PİLOT ' 'ZALANDO- alarmsız, fiyatsız'
#  'PRUSZCS GDANSKI' '-' 'RENK YANLIŞ' 'siyah renk iptal' 'İPTAL ORDER'
#  'Pre-shipment' 'pre-shipment' 'STRIPE OPT' 'SOLID Opt' '746 - Natural'
#  '800-Black' '902-Pink'
#  'orjınal po geldiğinde renk ve beden dağılımı girilecektir.'
#  'ORJ PO BEKLENIYOR' 'opd W05 // tod w10' 'opd w05 // tod w14'
#  'opd 8 / tod w14 ' 'iplik' 'CW U opd 19 Şubat  haftası'
#  'OPD W8 - TOD W14' 'OPD W9 - TOD W16 ' 'pr shipment' 'tod 17 opd?' 'UEX'
#  'tod w17 -- opd?'
#  'kalite hisar iplikte onaylı fakat forte ve save de geliştiriliyor. opd 6 Mayıs'
#  'OPD W10 /TOD W 19' 'OPD W10 /TOD W 18' 'OPD W10 /TOD W 20' 'OPD W09 '
#  'opd w12 tod w18' 'TOD W17' 'OPD W18' 'opd w14 tpd w21' 'opd w13 tod w19'
#  'opd w12 tod w21' 'opd w12 tod w19'
#  'OPD W14, renkler için l/d gidecek. Aba Tekstil'
#  'berlin antrasit renginde olacak beden rengi. opd W13' 'OPD W16 TOD W21'
#  'OPD W11' 'CW UU opd w18' 'CW UU opd w19' 'tod 17 ' 'tod 17 -- opd ? '
#  'SADECE HAM İPLİK ALIMI İÇİN AÇILDI'
#  'sadece iplik alımı için açıldı . kumaş gramaj 260 gr olacak'
#  '8 ayrı baskılı varyanta ortalama 10-15k adet gelecek' 'opd 13 - tod w19'
#  'CW P OPDW13' 'CW RR opd W13' 'CW UU opd w13' 'CW Y opd W13'
#  'CW QQ opd W16' 'ISW21 / CW26' 'OPD W14 TOD19' 'OPD W14 TOD20'
#  'OPD W14 TOD21' 'OPD W14 TOD22' 'CW RR Gorillaz OPD W13' '928953-8716'
#  'OPD W21 EU SS & OL' 'OPD W22 EU SS & OL' 'OPD W23 EU SS & OL'
#  'OE SÜPREM - RİBANA  TODW20' 'oe süprem-rib // tod w20' 'OPD21 TOD28'
#  'PENYE SÜPREM-RİBANA - // TODW20' 'penye süprem-rib. / tod w20' 'OPD W17'
#  'opd 19 - tod 24' 'OPDW18 // TODW23' 'opd w18- Tod w22 '
#  'varyant belli değil opd W16' 'Quick demand varyant belli değil opd W18'
#  'opd w17 tod w22' 'OPD 23 TOD 29' 'S24' 'W24'
#  'RENK KODU HENÜZ NET DEĞİL // opd w24- tod w32 - ısw 34' 'GEMİ'
#  'TIR YÜKLEMESİ' 'UÇAK S24' '24.836 adet cw17 -good riddance - todw24'
#  'splash tod w26' 'opd w19 tod w24' 'tod33 ' 'OPD33 TOD39'
#  'OPDW20 // TOD W26' 'OPD W23/TOD W31' 'online' 'shop' 'opd w24 tod w29'
#  'opd w22 tod w27' 'opd w24 tod w29 - GELECEK OLAN KOLEKSİYON SİPARİŞLERİ'
#  'ISW 30 - TOD W29 - OPD W23' 'ISW W34 - TOD W32 - OPD W27'
#  'ISW W38 - TOD W36 - OPD W31 ' 'ISW W42 - TOD W40 - OPD W35'
#  'ISW W46 - TOD W44 - OPD W39' 'opd w18 // tod w26 - w27'
#  'opd w21 tod w26' 'splash 1035155 - tod 26' 'splash 1035155 - tod 27'
#  'splash 1035155 - tod 28' 'splash 1035155 - tod 29'
#  'splash 1035155 - opd w26 tod 30' 'splash 1035155 -opd w27  tod 31'
#  'splash 1035155 - opd w28 tod 32' 'splash 1035155 - tod 36'
#  'splash 1035155 - tod 37' 'opd26 tod31' 'opd 30 tod35' 'opd 33 tod38'
#  'opd 37 tod42 ' 'TOD 26' 'PRE SHIPMENT' 'Opd w20  tod w26 '
#  'OPD W24 TOD W31 ' 'opd w18 todw24' 'Opd w21  tod w27' 'OPD22 TOD28'
#  'opd21 tod26 ' 'splash 1035155 -opd w21 tod 24'
#  'splash  opd w25 tod w28 ' 'splash opd w25 tod w29'
#  'splash opd w26 tod w30' 'splash opd27 tod w31' 'splash opd w28 tod w32'
#  'splash opd w29 tod w33' 'splash opd w30 tod w34'
#  'splash opd w32 tod w36' 'splash opd w33 tod w37'
#  'OPDW26 TODW32 CF00719 kalan 783 adet için' 'Opd w25  tod w31'
#  'OPD W24 - TOD W29 - ISW W31' 'OPD W24 - TOD W30 - ISW32'
#  'OPD W24 - TOD W29 - ISW31 ' 'OPD W24 - TOD W29 - ISW31' 'OPD W23'
#  'OPD W22 - TOD  W28' 'OPD W21' 'OPD23 TOD29' 'OPD 24 TOD 29']
# Model Kodu eşsiz değerleri = ['H&M05802' 'H&M05772' 'H&M05852' ... 'BER01438' 'ZAR03590' 'ZAR03557']
# Model Adı eşsiz değerleri = ['BRANDY TRS' 'SUSIE Raglan Dress s0 1251087D-8716 ALT 1'
#  'ROCKY LO LIC T-SHIRT 1216163D-7952' ... '8016-174 CR-985'
#  '5584-169 CONOSUR (UWM-4524) (ANIMAL PRINT)' '5584-631 (UWM-4731) ']
# Model Grup Kodu eşsiz değerleri = ['PTS' 'EBB' 'TSB' 'TSS' 'BDS' 'TSN' 'TPS' 'SWB' 'BLY' 'TPB' 'GMS' 'SG003'
#  'SWS' 'SG006' 'EBS' 'SWY' 'BLS' 'JCS' 'ETS' 'JCB' 'JCN' 'ATS' 'CRS' 'SRS'
#  'CRB' 'LGS' 'TKB' 'TLS' 'BDB' 'TKS' 'JGS' 'SWN' 'TPN' 'TSY' 'JGB' 'PTB'
#  'JGY' 'LGB' 'BLB' 'SRB' 'BRS' 'ATY' 'ATB' 'TLB' 'BLN' 'ETY' 'EBY' 'TPY'
#  'JGN' 'GMB' 'EBN' 'SG004' 'LGY' 'CBT' 'ETB' 'BDN' 'BDY' 'ATN' 'ACS' 'ETN']
# Model Grup Adı eşsiz değerleri = ['Solid Pantolon' 'Baskılı Elbise' 'Baskılı Tshirt' 'Solid Tshirt'
#  'Solid Body' 'Nakışlı Tshirt' 'Solid Top' 'Baskılı Sweatshirt'
#  'Yıkamalı Bluz' 'Baskılı Top' 'Solid Gömlek' 'Kapşonlu Sweatshirt'
#  'Solid Sweatshirt' 'Süveter' 'Solid Elbise' 'Yıkamalı Sweatshirt'
#  'Solid Bluz' 'Solid Jacket' 'Solid Etek' 'Baskılı Jacket'
#  'Nakışlı Jacket' 'Solid Atlet' 'Solid Cardigan' 'Solid Şort'
#  'Baskılı Cardigan' 'Solid Legging' 'Baskılı Set/Takım' 'Solid Tulum'
#  'Baskılı Body' 'Solid Set/Takım' 'Solid Jogger' 'Nakışlı Sweatshirt'
#  'Nakışlı Top' 'Yıkamalı Tshirt' 'Baskılı Jogger' 'Baskılı Pantolon'
#  'Yıkamalı Jogger' 'Baskılı Legging' 'Baskılı Bluz' 'Baskılı Şort'
#  'Solid Bra' 'Yıkamalı Atlet' 'Baskılı Atlet' 'Baskılı Tulum'
#  'Nakışlı Bluz' 'Yıkamalı Etek' 'Yıkamalı Elbise' 'Yıkamalı Top'
#  'Nakışlı Jogger' 'Baskılı Gömlek' 'Nakışlı Elbise' 'Üst'
#  'Yıkamalı Legging' 'Cepli Basic Tshirt' 'Baskılı Etek' 'Nakışlı Body'
#  'Yıkamalı Body' 'Nakışlı Atlet' 'Solid Accessories' 'Nakışlı Etek']
# Model Group Name eşsiz değerleri = ['Solid Trousers' 'Printed Dress' 'Printed Tshirt' 'Solid Tshirt'
#  'Solid Body' 'Embroidared Tshirt' 'Printed Sweatshirt' 'Washed Blouse'
#  'Solid Shirt' 'Hooded Sweatshirt ' 'Solid Sweatshirt' 'Sweater '
#  'Solid Dress' 'Washed Sweatshirt' 'Solid Blouse' 'Solid Jacket'
#  'Solid Skirt' 'Printed Jacket' 'Embroidared Jacket' 'Solid Tanktop'
#  'Solid Cardigan' 'Solid Shorts' 'Printed Cardigan' 'Solid Legging'
#  'Printed Set' 'Solid Jumpsuit' 'Printed Body' 'Solid Set'
#  'Embroidared Sweatshirt' 'Washed Tshirt' 'Printed Trousers'
#  'Washed Trousers' 'Printed Legging' 'Printed Blouse' 'Printed Shorts'
#  'Solid Bra' 'Washed Tanktop' 'Printed Tanktop' 'Printed Jumpsuit'
#  'Embroidared Blouse' 'Washed Skirt' 'Washed Dress' 'Embroidared Trousers'
#  'Printed Shirt' 'Embroidared Dress' 'Top ' 'Washed Legging'
#  'Pocket Tshirt' 'Printed Skirt' 'Embroidared Body' 'Washed Body'
#  'Embroidared Tanktop' 'Solid Accessories' 'Embroidared Skirt']
# Sezon eşsiz değerleri = ['H&M S 0' nan 'W24' 'H&M S 9' 'I-24' 'SS24' 'H&M S 7' 'H&M S 6' 'FW22'
#  'AW22' 'WINTER22' 'H&M S 5' 'SS23' 'SS22' 'AW21' 'H&M S 4' 'WINTER21'
#  'SS21' 'SUMMER22' '5' 'I-22' 'AW23' 'OAW22' 'W22' 'FW23' 'OSS23' '7'
#  'H&M S 8' '8' 'WINTER23' 'AW24' 'ss24' '9' '0' 'V24' 'S24']
# Müşteri eşsiz değerleri = ['H&M' 'ITX TRADING S.A' 'C&A Buying GmbH & Co. KG' 'New Look'
#  'LPP COMPANY' 'ASDA STORES LIMITED' 'WE Fashion' 'PRIMARK LIMITED'
#  'BERSHKA BSK ESPANA S.A.' 'BRANDDESING SA' 'INDITEX' 'Motelrocks UK Ltd'
#  'BRAVADO MERCHANDISE A DIVISION OF UNIVERSAL MUSIC GMBH' 'LC Waikiki'
#  'UNIVERSAL MUSIC SPAIN S.L.U'
#  'TUVAL SANAT GALERİSİ TEKS.TUR.SAN.TİC.LTD.ŞTİ.' 'MERCH TRAFFIC'
#  'COTTON DIVISION' 'ÜNİTEKS TEKSTİL GIDA SAN DIŞ TİC. A.Ş'
#  'PARK AGENCIES LTD' 'PRIMARK STORES LTD']
# Marka eşsiz değerleri = ['H&M' 'Zara' 'C&A' 'Bershka' 'New Look' 'Reserved' 'GEORGE'
#  'Stradivarius' 'WE Fashion' 'Primark' 'BRANDDESING SA' 'TREADLER'
#  'Motel Rocks' 'BRAVADO' 'Lc Waikiki'
#  'TUVAL SANAT GALERİSİ TEKS.TUR.SAN.TİC.LTD.ŞTİ.' 'Uniteks']
# Departman eşsiz değerleri = ['Hennes-Everyday-Tops (1636)' 'Young Girl (8716)' 'Divided Blue (7952)'
#  'Trf' 'H&M Men (5828)' 'Divided Collection Tops (1640)' 'Kids (344)'
#  'Divided Blue-Basic (5882)' 'Women Top' 'Dubbster-Young Boys (8748)'
#  'Boys (7648)' 'Men Premium' 'Men Basic' 'Men Light Graphic Jersey(7272)'
#  'Men Top' 'Yessica Basic' 'Sports (8490)' 'Bershka Sweatshirt' 'Women '
#  'HM Plus (1919)' 'Basic' 'LOGG Ladies (1660)' 'Kids Set & Dress (354)'
#  'Young Girl (8718)' 'Clockhouse' 'Men Street' 'Kids 915 '
#  'LOGG Ladies Basic (1670)' 'Clockhouse Boys' 'Yessica Shop'
#  'Divided Dress (1343)' 'Divided White (1644)' 'Men Tshirt'
#  'Hennes-Everyday-Basic (1676)' 'License Boys (7659)'
#  'Class 660-ClockHouse OL' 'Clockhouse Boys (707)' 'Divided White (1343)'
#  'Girls Legging' 'Maternity' 'Basic Top ' 'Women Bottom'
#  'Small Girls (7618)' 'Divided Plus (1652)' 'Girl Outdoor (7819)'
#  'Divided Tops Wowen (1543)' 'Ladies Jogging Top Sweat Set' 'Mama (2032)'
#  'BOYS' 'Tight (3608)' 'Young Boys (7848)' 'Men Soft'
#  'Kids Boy Project(8854)' 'HM Sport (8316)' 'Stradivarius'
#  'Ladies Top Jersey Hanging' 'Girls Skirt' 'Sweat Bottoms' 'Trend (1641)'
#  'Ladies Top' 'Kids Bottom (334)' 'Young Girl (8815)' 'BERSHKA'
#  'Women Conosur' 'LOGG Men-Heavyknit (5858)' 'Kids Exclusive (7757)'
#  'Ladies  Dress' 'Girls Dress' 'Active Wear (283)' 'Cut & Sewn'
#  'Girls Sweat' 'Small Girls (7922)' 'Small Girls (7616)'
#  'Innovation (7020)' 'Yessica Shop Bottoms (144)' 'LISANS' 'Baby' 'Casual'
#  'Divided  Test(4091)' 'Trf Conosur' 'Sport (280)' 'Dress & Skirt'
#  'Dress (260)' 'Soft Wowen' 'NPG LADIES' 'Girls Jogging Top' 'Weav (9740)'
#  'Boys Fleece' 'Boys Tshirt' 'Extreme Class (233) / Ladies Nightwear'
#  'Weekday Trousers (8404)' 'MAN PROJECTS (5771)' 'Ladies'
#  'MAN PROJECTS 2 (5741)' 'Clockhouse XL' 'Weekday Women (8121)'
#  'Boys Pant' 'Sweat Tops' 'MEN GYMWEAR' 'Divided White (1743)'
#  'Projects & Occasion (1545)' 'Ladies Clothing (08-28-81)'
#  'Underwear (1336)' 'CLK' 'KADIN ÖRME' 'Weekday Men(8201)'
#  'Divided Collection Dresses (1344)' 'Skirt/Pant ' 'NPG - Caslon'
#  'TUVAL SANAT GALERISI' 'Dress' 'Baby Basic (6515)' 'Young Boy (8768)'
#  'Campaing (3090)' 'Bershka Lisans' 'Arge' 'LOGG Men-Basic (5868)'
#  'South Hub(3010)' 'Baby Exclusive(6557)' 'Sport (8310) '
#  'Divided Black -Basic(1643)' 'Boy (7668)' 'Yessica Dress (024)' 'UNITEKS'
#  'Small Girl Basic (7920)' 'Men Jogging Top/Knitted Trousers'
#  'Berhska Bottom' 'Sport MEN (8558)' 'Sport MEN (8394)' 'LOGG Men (5848)'
#  'Hennes-Everyday- Dress/Skirt (1322)' 'Sport Kids (6283) ' 'Girls Tshirt'
#  'Toddler (346)' 'Light Basic Jersey (5832)'
#  'Divided Collection -Basic (1645)' 'G21' 'Basic Big  Girl (7930)'
#  'Small Boys License(7878)' 'Sports Kids Girl (6280)' 'MONKI (3301) '
#  'MONKI (3304)' 'Divided Collection Skirt (1444)' 'MONKI (3306)'
#  'Weekday Women (8401)' 'Heavy Graphic Jersey(7273)'
#  'Kids Boys Top Toddler(446)' 'Canda Men (603)'
#  'Toddler Set & Dress (356)' 'Monki-dress (3307)' 'Kids Boy (7656)']
# Tedarik Grubu eşsiz değerleri = ['TBC 1' '11-109' '10-204' ... '77-214' '76-206' '13-218']
# Ülke Kodu eşsiz değerleri = ['TR' 'LH' 'OE' 'OF' 'OG' 'OO' 'SW' 'BE' 'CA' 'CH' 'CO' 'DE' 'DK' 'EC'
#  'GB' 'HR' 'IX' 'ME' 'MX' 'PA' 'PL' 'RS' 'SE' 'US' nan 'OE PLW237' 'OT'
#  'DR' 'LD-L3' 'OD' 'OU' 'SW PLW067' 'OB' 'AT' 'OL' 'ES' 'FR' 'NL' 'SK'
#  'OI' 'OJ' 'OK' 'NH' 'AU' 'CL' 'PE' 'UY' 'ZA' 'TH' 'VN' 'OE NLW174'
#  'THW263' 'LH ITW128' 'SW SEW065' 'IDW262' 'OE PLW067' 'OF ITW128' 'OR'
#  'OF ESW267' 'CN' 'DC' 'HK' 'ID' 'IN' 'JP' 'KR' 'MY' 'PH' 'TW' 'LH PLW256'
#  'NO' 'RU' 'OU USW068' 'NZ' 'OU USW305' 'UK' 'IB' 'NE1-MGB' 'NE2-BOR'
#  'ROI' 'ROO' 'USA' 'OE DEW255' 'ITW018' 'EW' 'WC' 'DD (WAYR7)' 'OW'
#  'NUM-IT' 'NUM-PL' 'NUM-HR' 'MP' 'MRC' 'EB' 'GPG' 'PP' 'OG GBW264' 'WW'
#  'BARCELONA' 'EJ' 'OI-LO' 'Pruszcz Gdanski' 'KCH Port' 'UK Trial' 'EM'
#  'YM' 'MJ' 'LO' 'EI' 'WM DED002' 'NB' 'WM GBD001' 'WM' 'BEW014-BE'
#  'BEW015-BE' 'ESW038' 'WW DED002' 'WW GBD001']
# Sipariş Adedi
# Döviz Türü eşsiz değerleri = ['EUR' 'YOK!' 'GBP' 'USD' 'TL']
# Döviz Birim Fiyat
# Döviz Ciro
# EUR Ciro
# Etüt Makina Dk
# Toplam Etüt Makina Dk
# Etüt Dk
# Toplam Etüt Dk
# MA_WorkOrder_RecId
# NetsisProjectCode eşsiz değerleri = ['HM01' 'ZR05' 'CA04' 'BM06' 'ING09' 'ZR08']
# Booking Statüsü eşsiz değerleri = ['Tedarik' nan 'Kapasite']
# Order Tipi - Durum eşsiz değerleri = ['Firm Order - Açık' 'Booking Order - Açık' 'Booking Order - Kapalı'
#  'Firm Order - Kapalı']
# C:\Users\halilibrahim.hatun\AppData\Local\Temp\ipykernel_2080\3284079472.py:2: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if siparis_df[column].dtype == 'object' or pd.api.types.is_categorical_dtype(siparis_df[column]):

# %%
siparis_df.columns
# Out:
# Index(['Durum', 'Statü', 'Booking -> Order', 'Set Order', 'Set Parça Sayısı',
#        'Order Tipi', 'Booking Type', 'Order Grubu', 'Satış Tipi',
#        'Sertifikasyon', 'Order No', 'Order Geliş Tarihi',
#        'Sisteme Giriş Tarihi', 'Satır ya da Sütun M.İsteme Tarihi', 'YIL',
#        'AY', 'HAFTA', 'ÇEYREK', 'Müşteri Order No', 'RPT', 'Açıklama',
#        'Model Kodu', 'Model Adı', 'Model Grup Kodu', 'Model Grup Adı',
#        'Model Group Name', 'Sezon', 'Müşteri', 'Marka', 'Departman',
#        'Tedarik Grubu', 'Ülke Kodu', 'Sipariş Adedi', 'Döviz Türü',
#        'Döviz Birim Fiyat', 'Döviz Ciro', 'EUR Ciro', 'Etüt Makina Dk',
#        'Toplam Etüt Makina Dk', 'Etüt Dk', 'Toplam Etüt Dk',
#        'MA_WorkOrder_RecId', 'NetsisProjectCode', 'Booking Statüsü',
#        'Order Tipi - Durum'],
#       dtype='object')

# %%
from langchain.chat_models import ChatOpenAI

def get_gpt_llm():
    chat_params = {
        "model": "gpt-4o", # Bigger context window
        "openai_api_key": os.environ['OPENAI_API_KEY'],
        "temperature": 0.2, # To avoid pure copy-pasting from docs lookup
        "max_tokens": 4096 
    }
    llm = ChatOpenAI(**chat_params)
    return llm

llm = get_gpt_llm()

# %% [markdown]
# ## Main Router

# %%
prompt = PromptTemplate(
    template="""role: system, content: Sen bir yönlendiricisin. Görevin gelen isteği uygun kategoriye yönlendirmek. 

    Eğer gelen mesaj kolonları ve ilgili verileri*['Order No', 'Model Kodu', 'Model Adı', 'Müşteri', 'Bölüm', 'Tedarikçi',
       'Müşteri Order No', 'Rpt', 'Marka', 'Renk Kodu', 'İşlem', 'RSN',
       'Tarih', 'Adet', 'Kumaş', 'Kumaş Tipi', 'Kalite Tipi'] olan şirketin H&M, ZARA, Bershaka gibi markalara olan
       üretim* verilerini gösteren bir mesaj ise veya

       kolonları *['Durum', 'Statü', 'Booking -> Order', 'Set Order', 'Set Parça Sayısı',
       'Order Tipi', 'Booking Type', 'Order Grubu', 'Satış Tipi',
       'Sertifikasyon', 'Order No', 'Order Geliş Tarihi',
       'Sisteme Giriş Tarihi', 'Satır ya da Sütun M.İsteme Tarihi', 'YIL',
       'AY', 'HAFTA', 'ÇEYREK', 'Müşteri Order No', 'RPT', 'Açıklama',
       'Model Kodu', 'Model Adı', 'Model Grup Kodu', 'Model Grup Adı',
       'Model Group Name', 'Sezon', 'Müşteri', 'Marka', 'Departman',
       'Tedarik Grubu', 'Ülke Kodu', 'Sipariş Adedi', 'Döviz Türü',
       'Döviz Birim Fiyat', 'Döviz Ciro', 'EUR Ciro', 'Etüt Makina Dk',
       'Toplam Etüt Makina Dk', 'Etüt Dk', 'Toplam Etüt Dk',
       'MA_WorkOrder_RecId', 'NetsisProjectCode', 'Booking Statüsü',
       'Order Tipi - Durum'] olan şirketin sipariş durumları hakkında* verileri gösteren bir mesaj ise bu mesaja yanıt olarak sadece 'PostreSQL',
      
       \n\n


    Eğer gelen mesaj *kişilerin adı, soyad, departman, semt/oturduğu yer, işe giriş tarihi, izin hakkı, kullandığı izin sayısı, gibi bilgileri ve 
    servis plakası, şoför adı/kimin sürdüğü veya kullandığı, servisin konumu veya nereye gittiği* hakkındaki bilgilerden herhangi biri içeriyorsa yanıt olarak sadece 'MongoDB',

    \n\n

    Eğer gelen mesaj *ERP prosedürü ile ilgili veya seyahat prosedürü ile ilgili veya temsili/misafir ve ağırlama prosedürü* ile ilgiliyse yanıt olarak sadece
    'ChromaDB',

    \n\n

    Eğer gelen mesaj yukarıdakilerin hiçbiriyle hiç bir şekilde alakalı değilse senin işinin Logos şirketi için çalışmak olduğunu ve bu tür
    sorulara cevap veremeyeceğini söyle, eğer gelen mesaj yukarıdakilerle biraz alakalı ama tam değil. Biraz daha detaylandırması için konuyla 
    ilgili sorular sor
    
    \n\n\n
    role: 'user', content: {question},

    role: 'assisstant', content: 
    """,
    input_variables=["question"],
)
start = time.time()
question_router = prompt | llm 


question = "şirketimize misafir geldi ne ypamalıyız"
print(question_router.invoke({"question": question}).content)
end = time.time()
print(f"The time required to generate response by Router Chain in seconds:{end - start}")
# Out:
# ChromaDB
# The time required to generate response by Router Chain in seconds:0.44271183013916016

# %% [markdown]
# ## MongoDB Router

# %%
prompt = PromptTemplate(
    template="""'Rol': sistem, 'İçerik': Sen çalışan, izin ve servis yapılarını yönlendiren bir yönlendiricisin. 

    Eğer içerikte kişinin adı, soyadı, departmanı, semti ve işe giriş tarihi özelliklerinin herhangi biri kullanılırsa çıktı olarak sadece 'Çalışan',
    \n\n
    Eğer içerikte kişisel bilgilerin yanında, kişinin izin hakkı sayısı, kullanılan izin sayısı, kazanılan izin hakkı sayısı özelliklerinden herhangi
    biri varsa çıktı olarak sadece 'İzin',
    \n\n
    Eğer içerikte servislerle ilgili servis plakas, soförünün adı, servisin gideceği yer/konum özelliklerinin herhangi biri varsa çıktı olarak 'Servis'
    dön.
    \n\n
    Eğer çok belirleyici bir istem gelmediyse konuya bağlı olarak detaylandırmasını kibarca iste

    \n\n\n
    
    'Rol': kullanıcı, 'İçerik': {question}

    \n\n\n

    'Rol': asistan, 'İçerik': 
    """,
    input_variables=["question"],
)
start = time.time()
mongodb_router = prompt | llm 


question = "Tatil  ne kadar"
print(mongodb_router.invoke({"question": question}).content)
end = time.time()
print(f"The time required to generate response by the retrieval grader in seconds:{end - start}")
# Out:
# Tatil süresi hakkında daha fazla bilgi verebilmem için lütfen izin hakkı sayısı, kullanılan izin sayısı veya kazanılan izin hakkı sayısı gibi detayları paylaşır mısınız?
# The time required to generate response by the retrieval grader in seconds:1.5185785293579102

# %% [markdown]
# ## PostreSQL Router

# %% [markdown]
# It will be modified

# %%
prompt = PromptTemplate(
    template="""'Rol': sistem, 'İçerik': Sen bir yönlendiricisin. Görevin gelen isteği uygun kategoriye yönlendirmek. 

    Eğer gelen mesaj kolonları ve ilgili verileri *['Order No', 'Model Kodu', 'Model Adı', 'Müşteri', 'Bölüm', 'Tedarikçi',
       'Müşteri Order No', 'Rpt', 'Marka', 'Renk Kodu', 'İşlem', 'RSN',
       'Tarih', 'Adet', 'Kumaş', 'Kumaş Tipi', 'Kalite Tipi'] olan şirketin H&M, ZARA, Bershaka gibi markalara olan
       üretim* verilerini gösteren bir mesaj ise sadece 'Üretim',
    \n\n
    Eğer gelen mesaj, kolonları  *['Durum', 'Statü', 'Booking -> Order', 'Set Order', 'Set Parça Sayısı',
       'Order Tipi', 'Booking Type', 'Order Grubu', 'Satış Tipi',
       'Sertifikasyon', 'Order No', 'Order Geliş Tarihi',
       'Sisteme Giriş Tarihi', 'Satır ya da Sütun M.İsteme Tarihi', 'YIL',
       'AY', 'HAFTA', 'ÇEYREK', 'Müşteri Order No', 'RPT', 'Açıklama',
       'Model Kodu', 'Model Adı', 'Model Grup Kodu', 'Model Grup Adı',
       'Model Group Name', 'Sezon', 'Müşteri', 'Marka', 'Departman',
       'Tedarik Grubu', 'Ülke Kodu', 'Sipariş Adedi', 'Döviz Türü',
       'Döviz Birim Fiyat', 'Döviz Ciro', 'EUR Ciro', 'Etüt Makina Dk',
       'Toplam Etüt Makina Dk', 'Etüt Dk', 'Toplam Etüt Dk',
       'MA_WorkOrder_RecId', 'NetsisProjectCode', 'Booking Statüsü',
       'Order Tipi - Durum'] olan ve şirketin sipariş durumları hakkında* verileri gösteren bir mesaj ise bu mesaja yanıt
       olarak sadece 'Sipariş' dön
    \n\n
    Eğer çok belirleyici bir istem gelmediyse konuya bağlı olarak detaylandırmasını kibarca iste

    \n\n\n
    
    'Rol': kullanıcı, 'İçerik': {question}

    \n\n\n

    'Rol': asistan, 'İçerik': 
    """,
    input_variables=["question"],
)
start = time.time()
mongodb_router = prompt | llm 


question = "Ürünlerin üretim durumu "
print(mongodb_router.invoke({"question": question}).content)
end = time.time()
print(f"The time required to generate response by the retrieval grader in seconds:{end - start}")
# Out:
# Ürünlerin üretim durumu hakkında daha fazla bilgi verebilmem için lütfen verilerin kolon başlıklarını paylaşır mısınız? Bu şekilde size daha doğru bir yönlendirme yapabilirim.
# The time required to generate response by the retrieval grader in seconds:1.20219087600708

# %% [markdown]
# ## MongoDB Retriever

# %% [markdown]
# ### Defining

# %% [markdown]
# #### A. Config

# %%
# We will keep all global variables in an object to not pollute the global namespace.
class MyConfig(object):
   pass

MY_CONFIG = MyConfig()

MY_CONFIG.ATLAS_URI =  os.environ['MONGO_DB_CON_STRING']
MY_CONFIG.OPENAI_API_KEY = os.environ['OPENAI_API_KEY']
print("Keys are ready")
# Out:
# Keys are ready

# %% [markdown]
# #### B. Mongo (Atlas)

# %%
from pymongo import MongoClient


class AtlasClient():
    """
    Atlas (Mongo) class to run vector search algorithm.
    
    """
    def __init__ (self, altas_uri, dbname):
       self.mongodb_client = MongoClient(altas_uri)
       self.database = self.mongodb_client[dbname]
    
    
    ## A quick way to test if we can connect to Atlas instance
    def ping (self):
       self.mongodb_client.admin.command('ping')
    
    
    def get_collection (self, collection_name):
       collection = self.database[collection_name]
       return collection
    
    
    def find (self, collection_name, filter = {}, limit=10):
       collection = self.database[collection_name]
       items = list(collection.find(filter=filter, limit=limit))
       return items
    
    
    def vector_search(self, collection_name, index_name, attr_name, embedding_vector, limit=5):
       collection = self.database[collection_name]
       results = collection.aggregate([
           {
               '$vectorSearch': {
                   "index": index_name,
                   "path": attr_name,
                   "queryVector": embedding_vector,
                   "numCandidates": 50,
                   "limit": limit,
               }
           },
           ## We are extracting 'vectorSearchScore' here
           ## columns with 1 are included, columns with 0 are excluded
           {
               "$project": {
                   '_id' : 1,
                   'Element_Description' : 1,
                   "search_score": { "$meta": "vectorSearchScore" }
           }
           }
           ])
       return list(results)
    
    
    def close_connection(self):
       self.mongodb_client.close()

# %% [markdown]
# #### OpenAI

# %%
class OpenAIClient():
    """
    Open AI class that will be used for RAG
    
    """
    def __init__(self, api_key) -> None:
       self.client = OpenAI(
           api_key= api_key,  # defaults to os.environ.get("OPENAI_API_KEY")
       )
       # print ("OpenAI Client initialized!")
    

    
    def get_embedding(self, text: str,  model="text-embedding-3-large") -> list[float]:
       text = text.replace("\n", " ")
       resp = self.client.embeddings.create (
           input=[text],
           model=model  )
    
    
       return resp.data[0].embedding

# %% [markdown]
# ## Generator

# %%
## Continue

prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> You are an assistant for question-answering tasks. 
    Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. 
    Use three sentences maximum and keep the answer concise <|eot_id|><|start_header_id|>user<|end_header_id|>
    Question: {question} 
    Context: {context} 
    Answer: <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
    input_variables=["question", "document"],
)

# Post-processing
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Chain
start = time.time()
rag_chain = prompt | llm | StrOutputParser()

# %% [markdown]
# # Defining Nodes

# %%
from typing_extensions import TypedDict
from typing import List
from langchain.schema import Document
### State

class GraphState(TypedDict):
    question : str
    generation : str
    documents : List[str]

# %%
class MongoNodeClass():
    def __init__(self, db_indexes: List[str], collection_names: List[str], db_name: str, mongo_router):
        self.db_indexes = db_indexes
        self.collection_names = collection_names
    
        # Define router
        self.mongo_router = mongo_router
        
        # Define state
        self.state = GraphState()
        
        # my config
        self.myconfig = MyConfig()
        self.myconfig.ATLAS_URI = os.environ['MONGO_DB_CON_STRING']
        self.myconfig.OPENAI_API_KEY = os.environ['OPENAI_API_KEY']
        self.myconfig.DB_NAME = db_name # 'kuikaAI'
        self.atlas_clients = []
    
        # Run build atlas clients
        self.build_Atlas_clients()
        self.openai_client = OpenAIClient(api_key=self.myconfig.OPENAI_API_KEY)
        print("OpenAI Client is ready.")
    
    
    def build_Atlas_clients(self):
        """
        Atlas client connecting processes
        """
        
        for db_index_name, collection_name in zip(self.db_indexes, self.collection_names):
    
            self.myconfig.INDEX_NAME = db_index_name
            self.myconfig.COLLECTION_NAME = collection_name
    
            atlas_client = AtlasClient(self.myconfig.ATLAS_URI, self.myconfig.DB_NAME)
            atlas_client.ping()
            
            print(f"{collection_name} atlas is ready :)")
    
            self.atlas_clients.append(atlas_client)
            

    def do_vector_search(query:str, collection_name_parameter: str, k: int = 5) -> None:
        """
        DYNAMIC VECTOR SEARCH 
        """ 
        if collection_name_parameter == 'employee':
            index=0
        elif collection_name_parameter == 'izin':
            index=1
        elif collection_name_parameter == 'servis':
            index=2
        else:
            raise ValueError(f"{collection_name_parameter} could not found.")

        # Start the method
        query = query.lower().strip()  
        print ('query: ', query)
        
        
        # Query Embedding
        embedding = self.openai_client.get_embedding(query)
        

        
        # Vector Search
        results = atlas_client.vector_search(collection_name=MY_CONFIG.COLLECTION_NAME, index_name=MY_CONFIG.INDEX_NAME, 
                                            attr_name='Element_Description_embedding', embedding_vector=embedding, limit=k)
        
    

    def mongo_routing(self, state):
        """
        MONGO ROUTING
        """
        print("--- Mongo Routing Process ---")

        question = state["question"]
        response_text = mongodb_router.invoke({"question": question}).content
        print("Mongo Router => ", response_text)

        # Routing
        if "Çalışan" in response_text:
            return "Çalışan"

        elif "İzin" in response_text:
            return "İzin"

        elif "Servis" in response_text:
            return "Servis"

        else:
            return "Boş"

    def retrieve_employee(self, state):
        """
        EMPLOYEE RETRIEVING
        """
        question = state['question']
        self.do_vector_search()
        
    
    def retrieve_employee(self, state):
        pass
    
    
    def retrieve_employee(self, state):
        pass

# %% [markdown]
# Check running

# %%
mongo_db_indexes =  ['vector_index_employee', 'vector_index_izin', 'vector_index_servis']
collections = ['employee_list', 'izin_List', 'servis_list']

mongo_node_class = MongoNodeClass(db_indexes=mongo_db_indexes, collection_names=collections, db_name='kuikaAI')
# Out:
# employee_list atlas is ready :)
# izin_List atlas is ready :)
# servis_list atlas is ready :)

# %%
def retrieve_mongo_employee(state):
    """
    Retrieve documents from vectorstore

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, documents, that contains retrieved documents
    """
    print("---RETRIEVE---")
    question = state["question"]

    # Retrieval
    documents = retriever.invoke(question)
    return {"documents": documents, "question": question}
